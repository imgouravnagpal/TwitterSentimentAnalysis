# %%
import numpy as np
import pandas as pd
Traindata = pd.read_csv('Train.csv')
Testdata = pd.read_csv('Test.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
Traindata
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# ...

# %%
XTrain = [txt for txt in Traindata.text]
YTrain = [sentiment for sentiment in Traindata.airline_sentiment]
XTest = [txt for txt in Testdata.text]

# %%
count_vec = CountVectorizer(max_features = 2000,max_df=0.8, min_df=0.001)

# %%
X_Train_Transform = count_vec.fit_transform(XTrain)
X_Train_Transform
# Out:
# <10980x1472 sparse matrix of type '<class 'numpy.int64'>'
# 	with 153266 stored elements in Compressed Sparse Row format>

# %%
count_vec.get_feature_names()
# Out:
# ['000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1hr',
#  '1k',
#  '1st',
#  '20',
#  '200',
#  '2015',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '26',
#  '27',
#  '2hrs',
#  '2nd',
#  '30',
#  '35',
#  '36',
#  '3rd',
#  '40',
#  '400',
#  '45',
#  '50',
#  '500',
#  '60',
#  '700',
#  '728',
#  '75',
#  '800',
#  '90',
#  'aa',
#  'able',
#  'about',
#  'above',
#  'absolute',
#  'absolutely',
#  'acceptable',
#  'access',
#  'accommodate',
#  'account',
#  'actual',
#  'actually',
#  'add',
#  'added',
#  'adding',
#  'additional',
#  'address',
#  'advantage',
#  'advise',
#  'advisory',
#  'after',
#  'afternoon',
#  'again',
#  'agent',
#  'agents',
#  'ago',
#  'ah',
#  'ahead',
#  'air',
#  'aircraft',
#  'airline',
#  'airlines',
#  'airplane',
#  'airport',
#  'airports',
#  'airways',
#  'all',
#  'allow',
#  'allowed',
#  'allowing',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
# ...

# %% [markdown]
# Count vectorizer will remove all the stop words along with puntuations .. no need to do it manually

# %%
X_Test_Transform = count_vec.transform(XTest)

# %%
from sklearn.svm import SVC  #classifier

# %%
classifier = SVC()
classifier.fit(X_Train_Transform,YTrain) #fitting into classifier
# Out:
# SVC()

# %%
YTest = classifier.predict(X_Test_Transform)

# %%
classifier.score(X_Test_Transform,YTest) #score is pretty good
# Out:
# 1.0

# %%
np.savetxt('predictions.csv',YTest,'%s')
